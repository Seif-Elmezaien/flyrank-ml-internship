# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Seif-Elmezaien/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane: Refresh / Content Opportunity Scoring
#
# I chose the Refresh / Content Opportunity Scoring lane because it focuses on solving a practical business problem: identifying which webpages should be reviewed first when time and resources are limited. Rather than trying to review every page manually, this approach uses search and content signals to prioritize pages with the highest potential for improvement. I also chose this lane because it combines exploratory data analysis with machine learning to produce actionable recommendations, making it both technically interesting and directly useful for decision-making.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The goal of this project is to improve the decision of which webpages should be reviewed first for content refresh or improvement. The primary users are SEO specialists and content teams who have limited time and resources and cannot manually review every page.
#
# The output of this project is a ranked list of pages based on their estimated priority for review. Using this ranking, the team can focus on updating, expanding, optimizing, or monitoring the pages that are most likely to benefit from intervention.
#
# A wrong recommendation has two main costs. If a low-value page is prioritized, the team wastes time and effort on changes that provide little impact. If a high-potential page is missed, the opportunity to recover or increase organic traffic may be delayed or lost. The objective of this project is not to guarantee that refreshing a page will improve its performance, but to provide an evidence-based prioritization that helps the team make better decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The starter dataset contains **30000** webpages. Among them, **16262** pages show a declining trend, indicating that there are many candidates for review. Additionally, the average number of impressions over the last 90 days is **5200.3663**, showing that many pages receive meaningful search visibility. These observations suggest that prioritizing which pages to review could help content teams focus their efforts where they are likely to have the greatest impact.
#
# > Add blockquote

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Number of pages:", len(df))
print("Average impressions:", df["impressions_90d"].mean())
print("Median CTR:", df["ctr"].median())
print("Pages with declining trend:",
      (df["trend_direction"] == "down").sum())
# Out:
# Number of pages: 30000
# Average impressions: 5200.3663
# Median CTR: 0.07
# Pages with declining trend: 16262

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project is intended to provide decision support by identifying webpages that may be good candidates for content refresh based on patterns found in historical data. The results can help prioritize pages for review, but they should be used alongside human judgment rather than as automatic decisions.
#
# This work cannot prove that refreshing a page will increase its search performance, nor can it predict Google's ranking algorithm or future ranking changes with certainty. Any recommendations produced by the model represent statistical patterns observed in the available data, not causal relationships or guaranteed outcomes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
# ## Self-check
#
# * [x] Every section above is filled, including the markdown explanations and the supporting code.
# * [x] The notebook runs from top to bottom without errors (Runtime → Run all).
# * [x] No client names, URLs, or private search queries are included.
# * [x] My claims use careful language and are limited to observed patterns, measured results, directional insights, and decision support rather than causal conclusions.
# * [x] The notebook has been committed to the repository under `work/notebooks/`, and the repository URL is ready to submit.
